# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./fifa_eda.csv')

# %%
df['Year']=df.Date.dt.year
df['Month']=df.Date.dt.month
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# 0             FC Barcelona  110500.0  565.0           Left
# 1                 Juventus   77000.0  405.0          Right
# 2      Paris Saint-Germain  118500.0  290.0          Right
# 3        Manchester United   72000.0  260.0          Right
# 4          Manchester City  102000.0  355.0          Right
# ...                    ...       ...    ...            ...
# 18202      Crewe Alexandra      60.0    1.0          Right
# 18203       Trelleborgs FF      60.0    1.0          Right
# 18204     Cambridge United      60.0    1.0          Right
# 18205      Tranmere Rovers      60.0    1.0          Right
# 18206      Tranmere Rovers      60.0    1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                           5.0          4.0       RF    2004
# 1                           5.0          5.0       ST    2018
# 2                           5.0          5.0       LW    2017
# 3                           4.0          1.0       GK    2011
# 4                           4.0          4.0      RCM    2015
# ...                         ...          ...      ...     ...
# 18202                       1.0          2.0       CM    2017
# 18203                       1.0          2.0       ST    2018
# 18204                       1.0          2.0       ST    2017
# 18205                       1.0          2.0       RW    2018
# 18206                       1.0          2.0       CM    2018
#
#       Contract Valid Until    Height  Weight  Release Clause
# 0               2021-01-01  5.583333   159.0        226500.0
# 1               2022-01-01  6.166667   183.0        127100.0
# 2               2022-01-01  5.750000   150.0        228100.0
# 3               2020-01-01  6.333333   168.0        138600.0
# 4               2023-01-01  5.916667   154.0        196400.0
# ...                    ...       ...     ...             ...
# 18202           2019-01-01  5.750000   134.0           143.0
# 18203           2020-01-01  6.250000   170.0           113.0
# 18204           2021-01-01  5.666667   148.0           165.0
# 18205           2019-01-01  5.833333   154.0           143.0
# 18206           2019-01-01  5.833333   176.0           165.0
#
# [18207 rows x 18 columns]

# %%
df = pd.read_csv('./fifa_eda.csv', parse_dates = ['Contract Valid Until'])

# %%
df.rename(columns={'Contract Valid Until': 'Contract_Valid_Until'}, inplace=True)

# %%
df.rename(columns={'Potential': 'Contract_Valid_Until'}, inplace=True)

# %%
df['Year']=df.Contract_Valid_Until.dt.year
df['Month']=df.Contract_Valid_Until.dt.month

# %%
df.drop(columns=['ID'], inplace=True)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
#        'Wage', 'Preferred Foot', 'International Reputation', 'Skill Moves',
#        'Position', 'Joined', 'Contract_Valid_Until', 'Height', 'Weight',
#        'Release Clause', 'Year', 'Month'],
#       dtype='object')

# %%
df
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# 0                L. Messi   31   Argentina       94         94
# 1       Cristiano Ronaldo   33    Portugal       94         94
# 2               Neymar Jr   26      Brazil       92         93
# 3                  De Gea   27       Spain       91         93
# 4            K. De Bruyne   27     Belgium       91         92
# ...                   ...  ...         ...      ...        ...
# 18202        J. Lundstram   19     England       47         65
# 18203  N. Christoffersson   19      Sweden       47         63
# 18204           B. Worman   16     England       47         67
# 18205      D. Walker-Rice   17     England       47         66
# 18206           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# 0             FC Barcelona  110500.0  565.0           Left
# 1                 Juventus   77000.0  405.0          Right
# 2      Paris Saint-Germain  118500.0  290.0          Right
# 3        Manchester United   72000.0  260.0          Right
# 4          Manchester City  102000.0  355.0          Right
# ...                    ...       ...    ...            ...
# 18202      Crewe Alexandra      60.0    1.0          Right
# 18203       Trelleborgs FF      60.0    1.0          Right
# 18204     Cambridge United      60.0    1.0          Right
# 18205      Tranmere Rovers      60.0    1.0          Right
# 18206      Tranmere Rovers      60.0    1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                           5.0          4.0       RF    2004
# 1                           5.0          5.0       ST    2018
# 2                           5.0          5.0       LW    2017
# 3                           4.0          1.0       GK    2011
# 4                           4.0          4.0      RCM    2015
# ...                         ...          ...      ...     ...
# 18202                       1.0          2.0       CM    2017
# 18203                       1.0          2.0       ST    2018
# 18204                       1.0          2.0       ST    2017
# 18205                       1.0          2.0       RW    2018
# 18206                       1.0          2.0       CM    2018
#
#       Contract_Valid_Until    Height  Weight  Release Clause    Year  Month
# 0               2021-01-01  5.583333   159.0        226500.0  2021.0    1.0
# 1               2022-01-01  6.166667   183.0        127100.0  2022.0    1.0
# 2               2022-01-01  5.750000   150.0        228100.0  2022.0    1.0
# 3               2020-01-01  6.333333   168.0        138600.0  2020.0    1.0
# 4               2023-01-01  5.916667   154.0        196400.0  2023.0    1.0
# ...                    ...       ...     ...             ...     ...    ...
# 18202           2019-01-01  5.750000   134.0           143.0  2019.0    1.0
# 18203           2020-01-01  6.250000   170.0           113.0  2020.0    1.0
# 18204           2021-01-01  5.666667   148.0           165.0  2021.0    1.0
# 18205           2019-01-01  5.833333   154.0           143.0  2019.0    1.0
# 18206           2019-01-01  5.833333   176.0           165.0  2019.0    1.0
#
# [18207 rows x 19 columns]

# %% [markdown]
# ### Is there a correlation between a player's age and their overall rating?

# %%
sns.barplot(x='Age', y='Overall', data=df)
plt.title("Age vs. Overall Rating")
plt.xlabel("Age")
plt.ylabel("Overall Rating")
plt.show()

# %%
correlation = df['Age'].corr(df['Overall'])
print("Correlation coefficient:", correlation)
# Out:
# Correlation coefficient: 0.45234952145633534

# %% [markdown]
# ### Is there a correlation between a player's age and their potential?

# %%
sns.barplot(x='Age', y='Potential', data=df)
plt.title("Age vs. Potential")
plt.xlabel("Age")
plt.ylabel("Potential")
plt.show()

# %%
correlation = df['Age'].corr(df['Potential'])
print("Correlation coefficient:", correlation)
# Out:
# Correlation coefficient: -0.2533121074109556

# %% [markdown]
# ### Are there any notable differences in the distribution of values and wages between players with different preferred foot (left or right)?

# %%
left_foot_players = df[df['Preferred Foot'] == 'Left']
right_foot_players = df[df['Preferred Foot'] == 'Right']
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(left_foot_players['Value'], bins=20, color='blue', label='Left Foot')
sns.histplot(right_foot_players['Value'], bins=20, color='orange', label='Right Foot')
plt.title("Distribution of Value by Preferred Foot")
plt.xlabel("Value")
plt.ylabel("Count")
plt.legend()

plt.subplot(1, 2, 2)
sns.histplot(left_foot_players['Wage'], bins=20, color='blue', label='Left Foot')
sns.histplot(right_foot_players['Wage'], bins=20, color='orange', label='Right Foot')
plt.title("Distribution of Wage by Preferred Foot")
plt.xlabel("Wage")
plt.ylabel("Count")
plt.legend()

plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
#        'Wage', 'Preferred Foot', 'International Reputation', 'Skill Moves',
#        'Position', 'Joined', 'Contract_Valid_Until', 'Height', 'Weight',
#        'Release Clause', 'Year', 'Month'],
#       dtype='object')

# %%
left_foot_players = df[df['Preferred Foot'] == 'Left']
right_foot_players = df[df['Preferred Foot'] == 'Right']
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(left_foot_players['Value'], bins=20, color='blue', label='Left Foot')
sns.histplot(right_foot_players['Value'], bins=20, color='orange', label='Right Foot')
plt.title("Distribution of Value by Preferred Foot")
plt.xlabel("Value")
plt.ylabel("Count")
plt.legend()

plt.subplot(1, 2, 2)
sns.histplot(left_foot_players['Wage'], bins=20, color='blue', label='Left Foot')
sns.histplot(right_foot_players['Wage'], bins=20, color='orange', label='Right Foot')
plt.title("Distribution of Wage by Preferred Foot")
plt.xlabel("Wage")
plt.ylabel("Count")
plt.legend()

plt.tight_layout()
plt.show()

# %%
df.Wage.max()
# Out:
# 565.0

# %%
df['Wage_limit'] = pd.cut(x = df.Wage, bins=[0,20, 50,100, 200,300, 600], labels=['Too Low','Low','Below_Avg','Medium','High', 'Too High'])
df
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# 0                L. Messi   31   Argentina       94         94
# 1       Cristiano Ronaldo   33    Portugal       94         94
# 2               Neymar Jr   26      Brazil       92         93
# 3                  De Gea   27       Spain       91         93
# 4            K. De Bruyne   27     Belgium       91         92
# ...                   ...  ...         ...      ...        ...
# 18202        J. Lundstram   19     England       47         65
# 18203  N. Christoffersson   19      Sweden       47         63
# 18204           B. Worman   16     England       47         67
# 18205      D. Walker-Rice   17     England       47         66
# 18206           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# 0             FC Barcelona  110500.0  565.0           Left
# 1                 Juventus   77000.0  405.0          Right
# 2      Paris Saint-Germain  118500.0  290.0          Right
# 3        Manchester United   72000.0  260.0          Right
# 4          Manchester City  102000.0  355.0          Right
# ...                    ...       ...    ...            ...
# 18202      Crewe Alexandra      60.0    1.0          Right
# 18203       Trelleborgs FF      60.0    1.0          Right
# 18204     Cambridge United      60.0    1.0          Right
# 18205      Tranmere Rovers      60.0    1.0          Right
# 18206      Tranmere Rovers      60.0    1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                           5.0          4.0       RF    2004
# 1                           5.0          5.0       ST    2018
# 2                           5.0          5.0       LW    2017
# 3                           4.0          1.0       GK    2011
# 4                           4.0          4.0      RCM    2015
# ...                         ...          ...      ...     ...
# 18202                       1.0          2.0       CM    2017
# 18203                       1.0          2.0       ST    2018
# 18204                       1.0          2.0       ST    2017
# 18205                       1.0          2.0       RW    2018
# 18206                       1.0          2.0       CM    2018
#
#       Contract_Valid_Until    Height  Weight  Release Clause    Year  Month  \
# 0               2021-01-01  5.583333   159.0        226500.0  2021.0    1.0
# 1               2022-01-01  6.166667   183.0        127100.0  2022.0    1.0
# 2               2022-01-01  5.750000   150.0        228100.0  2022.0    1.0
# 3               2020-01-01  6.333333   168.0        138600.0  2020.0    1.0
# 4               2023-01-01  5.916667   154.0        196400.0  2023.0    1.0
# ...                    ...       ...     ...             ...     ...    ...
# 18202           2019-01-01  5.750000   134.0           143.0  2019.0    1.0
# 18203           2020-01-01  6.250000   170.0           113.0  2020.0    1.0
# 18204           2021-01-01  5.666667   148.0           165.0  2021.0    1.0
# 18205           2019-01-01  5.833333   154.0           143.0  2019.0    1.0
# 18206           2019-01-01  5.833333   176.0           165.0  2019.0    1.0
#
#       Wage_limit
# 0       Too High
# 1       Too High
# 2           High
# 3           High
# 4       Too High
# ...          ...
# 18202    Too Low
# 18203    Too Low
# 18204    Too Low
# 18205    Too Low
# 18206    Too Low
#
# [18207 rows x 20 columns]

# %%
Foot_Wage_Value = pd.pivot_table(data=df, values='Value', index='Wage_limit', columns='Preferred Foot')
Foot_Wage_Value
# Out:
# Preferred Foot          Left         Right
# Wage_limit
# Too Low          1337.947802   1199.558449
# Low              7210.119048   7450.809444
# Below_Avg       15411.956522  15291.362126
# Medium          29957.142857  28948.113208
# High            54000.000000  57225.000000
# Too High        80000.000000  74100.000000

# %%
Foot_Wage_Value.plot.bar();

# %%
df1=df[['Value',
       'Wage', 'Preferred Foot']]

# %%
df1
# Out:
#           Value   Wage Preferred Foot
# 0      110500.0  565.0           Left
# 1       77000.0  405.0          Right
# 2      118500.0  290.0          Right
# 3       72000.0  260.0          Right
# 4      102000.0  355.0          Right
# ...         ...    ...            ...
# 18202      60.0    1.0          Right
# 18203      60.0    1.0          Right
# 18204      60.0    1.0          Right
# 18205      60.0    1.0          Right
# 18206      60.0    1.0          Right
#
# [18207 rows x 3 columns]

# %%
footvsvalue = df.groupby('Preferred Foot')['Value'].mean()
footvsvalue.plot.bar();

# %%
footvswage = df.groupby('Preferred Foot')['Wage'].mean()
footvswage.plot.bar()
# Out:
# <AxesSubplot:xlabel='Preferred Foot'>

# %%
footvsvalue = df.groupby('Preferred Foot')['Value'].mean()

# %%
df2
# Out:
#          Value   Wage Preferred Foot
# 0     110500.0  565.0           Left
# 1      77000.0  405.0          Right
# 2     118500.0  290.0          Right
# 3      72000.0  260.0          Right
# 4     102000.0  355.0          Right
# ...        ...    ...            ...
# 3424    4600.0   54.0          Right
# 3672    2600.0   71.0          Right
# 3684    6000.0   58.0           Left
# 3788    3900.0   51.0          Right
# 5140    2800.0   57.0          Right
#
# [578 rows x 3 columns]

# %% [markdown]
# ### Are there any correlations between a player's position and their overall rating or potential?

# %%
position_rating = df.groupby('Position')['Overall'].mean()
position_potential = df.groupby('Position')['Potential'].mean()
position_rating.plot.bar()
# Out:
# <AxesSubplot:xlabel='Position'>

# %%
position_potential.plot.bar()
# Out:
# <AxesSubplot:xlabel='Position'>

# %% [markdown]
# ### How does the international recognition correlate with their overall rating?

# %%
recogvsoverall=df.groupby('International Reputation')['Overall'].mean()
recogvsoverall.plot.bar()
# Out:
# <AxesSubplot:xlabel='International Reputation'>

# %% [markdown]
# ### How does a player's skill moves rating relate to their overall rating?

# %%
players_with_international_recognition = df[df['International Reputation'] > 0]

# %%
skillvsoverall=df.groupby('Skill Moves')['Overall'].mean()
skillvsoverall.plot.bar()
# Out:
# <AxesSubplot:xlabel='Skill Moves'>

# %%
sns.boxplot(x='International Reputation', y='Overall', data=players_with_international_recognition)
plt.title("International Reputation vs. Overall Rating")
plt.xlabel("International Reputation")
plt.ylabel("Overall Rating")
plt.show()

# %%
sns.scatterplot(x='International Reputation', y='Overall', data=players_with_international_recognition)
plt.title("International Reputation vs. Overall Rating")
plt.xlabel("International Reputation")
plt.ylabel("Overall Rating")
plt.show()

# %%
correlation = df['Skill Moves'].corr(df['Overall'])
print("Correlation coefficient:", correlation)
# Out:
# Correlation coefficient: 0.4144632351026756

# %% [markdown]
# ### Which club spend the most?

# %%
club_spending = df.groupby('Club')['Value'].sum().sort_values(ascending=False)
most_spending_club = club_spending.index[0]
total_spending = club_spending.iloc[0]

print("Club with the most spending:", most_spending_club)
print("Total spending:", total_spending)
# Out:
# Club with the most spending: Real Madrid
# Total spending: 874425.0

# %%
top_5_clubs = club_spending.head(5)

plt.bar(top_5_clubs.index, top_5_clubs.values)
plt.title("Top 5 Clubs with the Highest Spending")
plt.xlabel("Club")
plt.ylabel("Total Spending")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### How does a player's contract validity affect their overall rating or value?

# %%
#?????

# %%
sns.boxplot(x=df['Year'], y=df['Overall'])
plt.title("Contract Validity vs. Overall Rating")
plt.xlabel("Contract Valid Until")
plt.ylabel("Overall Rating")
plt.xticks(rotation=45)
plt.show()x

# %% [markdown]
# ### Are there any interesting insights related to the heights and weights of the players?

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Height', y='Weight', data=df)
plt.title("Height vs. Weight")
plt.xlabel("Height")
plt.ylabel("Weight")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Height'], kde=True)
plt.title("Distribution of Player Heights")
plt.xlabel("Height")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Weight'], kde=True)
plt.title("Distribution of Player Weights")
plt.xlabel("Weight")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Which clubs have the highest average overall rating?

# %%
average_ratings = df.groupby('Club')['Overall'].mean().sort_values(ascending=False)

# %%
plt.bar(highest_rated_clubs.index, highest_rated_clubs.values)
plt.title("Top-rated Clubs by Average Overall Rating")
plt.xlabel("Club")
plt.ylabel("Average Overall Rating")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Which nationalities are the most represented in the dataset?

# %%
highest_rated_clubs = average_ratings.head(5)

print("Clubs with the Highest Average Overall Rating:")
for club, rating in highest_rated_clubs.items():
    print(club, "-", rating)
# Out:
# Clubs with the Highest Average Overall Rating:
# Juventus - 82.28
# Napoli - 80.0
# Inter - 79.75
# Real Madrid - 78.24242424242425
# Milan - 78.07407407407408

# %%
nationality_counts = df['Nationality'].value_counts()
top_nationalities = nationality_counts.head(5)

# %%
plt.bar(top_nationalities.index, top_nationalities.values)
plt.title("Top Represented Nationalities")
plt.xlabel("Nationality")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Which nationalities have the highest overall rating in the dataset?

# %%
ratings = df.groupby('Nationality')['Overall'].sum().sort_values(ascending=False)
highest_rated_nationalities = ratings.head(5)
highest_rated_nationalities
# Out:
# Nationality
# England      105420
# Germany       79172
# Spain         74717
# Argentina     64252
# France        61968
# Name: Overall, dtype: int64

# %%
df.Nationality.value_counts()
# Out:
# England                 1662
# Germany                 1198
# Spain                   1072
# Argentina                937
# France                   914
#                         ...
# New Caledonia              1
# Fiji                       1
# São Tomé & Príncipe        1
# United Arab Emirates       1
# Botswana                   1
# Name: Nationality, Length: 164, dtype: int64

# %%
df
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# 0                L. Messi   31   Argentina       94         94
# 1       Cristiano Ronaldo   33    Portugal       94         94
# 2               Neymar Jr   26      Brazil       92         93
# 3                  De Gea   27       Spain       91         93
# 4            K. De Bruyne   27     Belgium       91         92
# ...                   ...  ...         ...      ...        ...
# 18202        J. Lundstram   19     England       47         65
# 18203  N. Christoffersson   19      Sweden       47         63
# 18204           B. Worman   16     England       47         67
# 18205      D. Walker-Rice   17     England       47         66
# 18206           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# 0             FC Barcelona  110500.0  565.0           Left
# 1                 Juventus   77000.0  405.0          Right
# 2      Paris Saint-Germain  118500.0  290.0          Right
# 3        Manchester United   72000.0  260.0          Right
# 4          Manchester City  102000.0  355.0          Right
# ...                    ...       ...    ...            ...
# 18202      Crewe Alexandra      60.0    1.0          Right
# 18203       Trelleborgs FF      60.0    1.0          Right
# 18204     Cambridge United      60.0    1.0          Right
# 18205      Tranmere Rovers      60.0    1.0          Right
# 18206      Tranmere Rovers      60.0    1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                           5.0          4.0       RF    2004
# 1                           5.0          5.0       ST    2018
# 2                           5.0          5.0       LW    2017
# 3                           4.0          1.0       GK    2011
# 4                           4.0          4.0      RCM    2015
# ...                         ...          ...      ...     ...
# 18202                       1.0          2.0       CM    2017
# 18203                       1.0          2.0       ST    2018
# 18204                       1.0          2.0       ST    2017
# 18205                       1.0          2.0       RW    2018
# 18206                       1.0          2.0       CM    2018
#
#       Contract_Valid_Until    Height  Weight  Release Clause    Year  Month  \
# 0               2021-01-01  5.583333   159.0        226500.0  2021.0    1.0
# 1               2022-01-01  6.166667   183.0        127100.0  2022.0    1.0
# 2               2022-01-01  5.750000   150.0        228100.0  2022.0    1.0
# 3               2020-01-01  6.333333   168.0        138600.0  2020.0    1.0
# 4               2023-01-01  5.916667   154.0        196400.0  2023.0    1.0
# ...                    ...       ...     ...             ...     ...    ...
# 18202           2019-01-01  5.750000   134.0           143.0  2019.0    1.0
# 18203           2020-01-01  6.250000   170.0           113.0  2020.0    1.0
# 18204           2021-01-01  5.666667   148.0           165.0  2021.0    1.0
# 18205           2019-01-01  5.833333   154.0           143.0  2019.0    1.0
# 18206           2019-01-01  5.833333   176.0           165.0  2019.0    1.0
#
#       Wage_limit
# 0       Too High
# 1       Too High
# 2           High
# 3           High
# 4       Too High
# ...          ...
# 18202    Too Low
# 18203    Too Low
# 18204    Too Low
# 18205    Too Low
# 18206    Too Low
#
# [18207 rows x 20 columns]

# %%
plt.bar(highest_rated_nationalities.index, highest_rated_nationalities.values)
plt.title("Top-rated Nationalities by Overall Rating")
plt.xlabel("Nationality")
plt.ylabel("Overall Rating")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### What are the most common positions played by the players?

# %%
position_counts = df['Position'].value_counts()
top_positions = position_counts.head(10)
plt.bar(top_positions.index, top_positions.values)
plt.title("Most Common Positions")
plt.xlabel("Position")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
position_nationalities = df.groupby('Position')['Nationality'].value_counts()
for position in df['Position'].unique():
    print("Position:", position)
    print(position_nationalities[position])
    print()
# Out:
# Position: RF
# Nationality
# Japan        3
# Argentina    2
# Belgium      2
# Austria      1
# China PR     1
# Finland      1
# Germany      1
# Italy        1
# Spain        1
# Sweden       1
# Syria        1
# Uruguay      1
# Name: Nationality, dtype: int64
#
# Position: ST
# Nationality
# England                226
# Argentina              125
# Brazil                 111
# Spain                  109
# France                 106
#                       ...
# South Sudan              1
# St Kitts Nevis           1
# Sudan                    1
# Syria                    1
# São Tomé & Príncipe      1
# Name: Nationality, Length: 114, dtype: int64
#
# Position: LW
# Nationality
# Italy        32
# Argentina    27
# England      18
# France       16
# Brazil       15
#              ..
# Togo          1
# Uganda        1
# Ukraine       1
# Wales         1
# Zimbabwe      1
# Name: Nationality, Length: 81, dtype: int64
#
# Position: GK
# Nationality
# England              174
# Germany              164
# Spain                116
# France               101
# Argentina             97
#                     ...
# Namibia                1
# Nigeria                1
# Oman                   1
# Philippines            1
# Trinidad & Tobago      1
# Name: Nationality, Length: 94, dtype: int64
#
# Position: RCM
# Nationality
# England      37
# Spain        28
# Argentina    18
# Denmark      18
# Germany      18
#              ..
# Tunisia       1
# Uganda        1
# Ukraine       1
# Wales         1
# Zimbabwe      1
# Name: Nationality, Length: 64, dtype: int64
#
# Position: LF
# Nationality
# Argentina        3
# Belgium          2
# Japan            2
# Spain            2
# Brazil           1
# Costa Rica       1
# Estonia          1
# FYR Macedonia    1
# Georgia          1
# Germany          1
# Name: Nationality, dtype: int64
#
# Position: RS
# Nationality
# England                28
# Germany                19
# Italy                  17
# Spain                  11
# Argentina              10
# Brazil                  8
# France                  8
# Colombia                7
# Japan                   6
# Ivory Coast             4
# Scotland                4
# Uruguay                 4
# Austria                 3
# Belgium                 3
# Chile                   3
# Korea Republic          3
# Mexico                  3
# Netherlands             3
# Nigeria                 3
# Poland                  3
# Saudi Arabia            3
# Sweden                  3
# Australia               2
# Benin                   2
# Croatia                 2
# Denmark                 2
# Republic of Ireland     2
# Russia                  2
# Senegal                 2
# Serbia                  2
# Turkey                  2
# Venezuela               2
# Wales                   2
# Albania                 1
# Angola                  1
# Azerbaijan              1
# Bolivia                 1
# Cameroon                1
# Canada                  1
# China PR                1
# Czech Republic          1
# DR Congo                1
# Ecuador                 1
# Fiji                    1
# Ghana                   1
# India                   1
# Israel                  1
# Jamaica                 1
# Mali                    1
# Montserrat              1
# Morocco                 1
# New Zealand             1
# Northern Ireland        1
# Norway                  1
# Panama                  1
# Portugal                1
# United States           1
# Zimbabwe                1
# Name: Nationality, dtype: int64
#
# Position: RCB
# Nationality
# England        56
# Germany        48
# Brazil         39
# Argentina      37
# Spain          36
#                ..
# New Zealand     1
# Peru            1
# Russia          1
# Togo            1
# Zambia          1
# Name: Nationality, Length: 80, dtype: int64
#
# Position: LCM
# Nationality
# England      33
# Spain        28
# Argentina    25
# Italy        19
# France       17
#              ..
# Tunisia       1
# Turkey        1
# Uganda        1
# Wales         1
# Zimbabwe      1
# Name: Nationality, Length: 73, dtype: int64
#
# Position: CB
# Nationality
# England         161
# Germany         128
# Spain           104
# Argentina        99
# France           93
#                ...
# Mauritius         1
# Peru              1
# Puerto Rico       1
# Qatar             1
# Sierra Leone      1
# Name: Nationality, Length: 103, dtype: int64
#
# Position: LDM
# Nationality
# Brazil          25
# Germany         23
# France          17
# Argentina       16
# England         13
#                 ..
# Slovakia         1
# Slovenia         1
# South Africa     1
# Sweden           1
# Wales            1
# Name: Nationality, Length: 63, dtype: int64
#
# Position: CAM
# Nationality
# Brazil                  81
# England                 72
# Germany                 62
# Spain                   57
# France                  51
#                         ..
# Nigeria                  1
# Syria                    1
# Trinidad & Tobago        1
# United Arab Emirates     1
# Zambia                   1
# Name: Nationality, Length: 85, dtype: int64
#
# Position: CDM
# Nationality
# Germany        79
# Spain          65
# France         63
# Argentina      55
# Colombia       54
#                ..
# New Zealand     1
# Romania         1
# Sudan           1
# Syria           1
# Venezuela       1
# Name: Nationality, Length: 88, dtype: int64
#
# Position: LS
# Nationality
# England                26
# Germany                18
# Italy                  16
# Brazil                 15
# Spain                  15
# Argentina              13
# Colombia                7
# Norway                  6
# Sweden                  6
# Uruguay                 6
# France                  5
# Republic of Ireland     5
# Denmark                 4
# Japan                   4
# Ghana                   3
# Netherlands             3
# Scotland                3
# Barbados                2
# Bosnia Herzegovina      2
# Chile                   2
# Gambia                  2
# Ivory Coast             2
# Korea Republic          2
# Mexico                  2
# Montenegro              2
# Morocco                 2
# Paraguay                2
# Poland                  2
# Senegal                 2
# Armenia                 1
# Australia               1
# Austria                 1
# Belgium                 1
# Bulgaria                1
# Cameroon                1
# Canada                  1
# Congo                   1
# Croatia                 1
# Cyprus                  1
# Ecuador                 1
# Eritrea                 1
# Finland                 1
# Guinea Bissau           1
# India                   1
# Israel                  1
# Jamaica                 1
# Nigeria                 1
# Portugal                1
# Romania                 1
# Serbia                  1
# Switzerland             1
# Syria                   1
# Thailand                1
# Tunisia                 1
# Ukraine                 1
# United States           1
# Venezuela               1
# Name: Nationality, dtype: int64
#
# Position: LCB
# Nationality
# England             54
# Brazil              47
# Germany             39
# France              37
# Argentina           35
#                     ..
# Nicaragua            1
# Northern Ireland     1
# Panama               1
# Russia               1
# Venezuela            1
# Name: Nationality, Length: 83, dtype: int64
#
# Position: RM
# Nationality
# England         115
# Germany          88
# Spain            82
# Argentina        62
# Colombia         52
#                ...
# South Africa      1
# Sudan             1
# Syria             1
# Thailand          1
# Uganda            1
# Name: Nationality, Length: 96, dtype: int64
#
# Position: LAM
# Nationality
# Brazil      13
# Colombia     2
# Japan        2
# Germany      1
# Serbia       1
# Uruguay      1
# Zambia       1
# Name: Nationality, dtype: int64
#
# Position: LM
# Nationality
# England              97
# Germany              94
# Spain                76
# Argentina            64
# France               49
#                      ..
# Montenegro            1
# Slovenia              1
# Tanzania              1
# Trinidad & Tobago     1
# Ukraine               1
# Name: Nationality, Length: 94, dtype: int64
#
# Position: LB
# Nationality
# England        129
# Germany         82
# Spain           82
# France          81
# Brazil          69
#               ...
# Nicaragua        1
# Philippines      1
# Syria            1
# Thailand         1
# Uganda           1
# Name: Nationality, Length: 99, dtype: int64
#
# Position: RDM
# Nationality
# Germany              24
# Brazil               22
# France               19
# England              13
# Colombia             12
#                      ..
# Romania               1
# Slovakia              1
# South Africa          1
# Sweden                1
# Trinidad & Tobago     1
# Name: Nationality, Length: 67, dtype: int64
#
# Position: RW
# Nationality
# Argentina    29
# Brazil       21
# France       20
# England      19
# Italy        19
#              ..
# Slovakia      1
# Slovenia      1
# Togo          1
# Tunisia       1
# Zambia        1
# Name: Nationality, Length: 69, dtype: int64
#
# Position: CM
# Nationality
# England     196
# Italy        90
# Spain        80
# Germany      60
# France       58
#            ...
# Slovenia      1
# Syria         1
# Thailand      1
# Tunisia       1
# Zambia        1
# Name: Nationality, Length: 96, dtype: int64
#
# Position: RB
# Nationality
# England           119
# Spain              87
# Germany            83
# France             74
# Brazil             63
#                  ...
# Slovakia            1
# St Kitts Nevis      1
# St Lucia            1
# Uganda              1
# Zimbabwe            1
# Name: Nationality, Length: 102, dtype: int64
#
# Position: RAM
# Nationality
# Brazil       14
# Colombia      2
# Japan         2
# Germany       1
# Morocco       1
# Venezuela     1
# Name: Nationality, dtype: int64
#
# Position: CF
# Nationality
# Japan             16
# Germany            5
# Italy              5
# Brazil             4
# Spain              4
# Sweden             4
# Korea Republic     3
# Argentina          2
# Austria            2
# Chile              2
# Czech Republic     2
# Finland            2
# Ghana              2
# Norway             2
# Scotland           2
# Turkey             2
# Burkina Faso       1
# Cameroon           1
# Curacao            1
# England            1
# Iceland            1
# Korea DPR          1
# Kosovo             1
# Lithuania          1
# Mexico             1
# Namibia            1
# Peru               1
# Poland             1
# Russia             1
# United States      1
# Zimbabwe           1
# Name: Nationality, dtype: int64
#
# Position: RWB
# Nationality
# England                15
# Germany                 9
# Sweden                  9
# Denmark                 8
# France                  4
# Spain                   4
# Wales                   4
# China PR                3
# Republic of Ireland     3
# Argentina               2
# Italy                   2
# Netherlands             2
# Scotland                2
# Switzerland             2
# Algeria                 1
# Australia               1
# Austria                 1
# Belgium                 1
# Bosnia Herzegovina      1
# Cameroon                1
# Colombia                1
# Croatia                 1
# Czech Republic          1
# Iceland                 1
# Ivory Coast             1
# Japan                   1
# Jordan                  1
# Mexico                  1
# New Zealand             1
# Norway                  1
# Saudi Arabia            1
# South Africa            1
# Name: Nationality, dtype: int64
#
# Position: LWB
# Nationality
# England                10
# Sweden                  9
# Germany                 7
# Argentina               4
# China PR                4
# Denmark                 4
# France                  4
# Spain                   4
# Netherlands             3
# Republic of Ireland     3
# Scotland                3
# Colombia                2
# Japan                   2
# Australia               1
# Austria                 1
# Cameroon                1
# Comoros                 1
# Faroe Islands           1
# Finland                 1
# Ghana                   1
# Iceland                 1
# Italy                   1
# New Zealand             1
# Nigeria                 1
# Northern Ireland        1
# Norway                  1
# Peru                    1
# Portugal                1
# Russia                  1
# Saudi Arabia            1
# Switzerland             1
# Wales                   1
# Name: Nationality, dtype: int64

# %%
df
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# 0                L. Messi   31   Argentina       94         94
# 1       Cristiano Ronaldo   33    Portugal       94         94
# 2               Neymar Jr   26      Brazil       92         93
# 3                  De Gea   27       Spain       91         93
# 4            K. De Bruyne   27     Belgium       91         92
# ...                   ...  ...         ...      ...        ...
# 18202        J. Lundstram   19     England       47         65
# 18203  N. Christoffersson   19      Sweden       47         63
# 18204           B. Worman   16     England       47         67
# 18205      D. Walker-Rice   17     England       47         66
# 18206           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# 0             FC Barcelona  110500.0  565.0           Left
# 1                 Juventus   77000.0  405.0          Right
# 2      Paris Saint-Germain  118500.0  290.0          Right
# 3        Manchester United   72000.0  260.0          Right
# 4          Manchester City  102000.0  355.0          Right
# ...                    ...       ...    ...            ...
# 18202      Crewe Alexandra      60.0    1.0          Right
# 18203       Trelleborgs FF      60.0    1.0          Right
# 18204     Cambridge United      60.0    1.0          Right
# 18205      Tranmere Rovers      60.0    1.0          Right
# 18206      Tranmere Rovers      60.0    1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                           5.0          4.0       RF    2004
# 1                           5.0          5.0       ST    2018
# 2                           5.0          5.0       LW    2017
# 3                           4.0          1.0       GK    2011
# 4                           4.0          4.0      RCM    2015
# ...                         ...          ...      ...     ...
# 18202                       1.0          2.0       CM    2017
# 18203                       1.0          2.0       ST    2018
# 18204                       1.0          2.0       ST    2017
# 18205                       1.0          2.0       RW    2018
# 18206                       1.0          2.0       CM    2018
#
#       Contract_Valid_Until    Height  Weight  Release Clause    Year  Month  \
# 0               2021-01-01  5.583333   159.0        226500.0  2021.0    1.0
# 1               2022-01-01  6.166667   183.0        127100.0  2022.0    1.0
# 2               2022-01-01  5.750000   150.0        228100.0  2022.0    1.0
# 3               2020-01-01  6.333333   168.0        138600.0  2020.0    1.0
# 4               2023-01-01  5.916667   154.0        196400.0  2023.0    1.0
# ...                    ...       ...     ...             ...     ...    ...
# 18202           2019-01-01  5.750000   134.0           143.0  2019.0    1.0
# 18203           2020-01-01  6.250000   170.0           113.0  2020.0    1.0
# 18204           2021-01-01  5.666667   148.0           165.0  2021.0    1.0
# 18205           2019-01-01  5.833333   154.0           143.0  2019.0    1.0
# 18206           2019-01-01  5.833333   176.0           165.0  2019.0    1.0
#
#       Wage_limit
# 0       Too High
# 1       Too High
# 2           High
# 3           High
# 4       Too High
# ...          ...
# 18202    Too Low
# 18203    Too Low
# 18204    Too Low
# 18205    Too Low
# 18206    Too Low
#
# [18207 rows x 20 columns]

# %%
df.head(30)
# Out:
#                  Name  Age Nationality  Overall  Potential  \
# 0            L. Messi   31   Argentina       94         94
# 1   Cristiano Ronaldo   33    Portugal       94         94
# 2           Neymar Jr   26      Brazil       92         93
# 3              De Gea   27       Spain       91         93
# 4        K. De Bruyne   27     Belgium       91         92
# 5           E. Hazard   27     Belgium       91         91
# 6           L. Modrić   32     Croatia       91         91
# 7           L. Suárez   31     Uruguay       91         91
# 8        Sergio Ramos   32       Spain       91         91
# 9            J. Oblak   25    Slovenia       90         93
# 10     R. Lewandowski   29      Poland       90         90
# 11           T. Kroos   28     Germany       90         90
# 12           D. Godín   32     Uruguay       90         90
# 13        David Silva   32       Spain       90         90
# 14           N. Kanté   27      France       89         90
# 15          P. Dybala   24   Argentina       89         94
# 16            H. Kane   24     England       89         91
# 17       A. Griezmann   27      France       89         90
# 18      M. ter Stegen   26     Germany       89         92
# 19        T. Courtois   26     Belgium       89         90
# 20    Sergio Busquets   29       Spain       89         89
# 21          E. Cavani   31     Uruguay       89         89
# 22           M. Neuer   32     Germany       89         89
# 23          S. Agüero   30   Argentina       89         89
# 24       G. Chiellini   33       Italy       89         89
# 25          K. Mbappé   19      France       88         95
# 26           M. Salah   26       Egypt       88         89
# 27           Casemiro   26      Brazil       88         90
# 28       J. Rodríguez   26    Colombia       88         89
# 29         L. Insigne   27       Italy       88         88
#
#                    Club     Value   Wage Preferred Foot  \
# 0          FC Barcelona  110500.0  565.0           Left
# 1              Juventus   77000.0  405.0          Right
# 2   Paris Saint-Germain  118500.0  290.0          Right
# 3     Manchester United   72000.0  260.0          Right
# 4       Manchester City  102000.0  355.0          Right
# 5               Chelsea   93000.0  340.0          Right
# 6           Real Madrid   67000.0  420.0          Right
# 7          FC Barcelona   80000.0  455.0          Right
# 8           Real Madrid   51000.0  380.0          Right
# 9       Atlético Madrid   68000.0   94.0          Right
# 10    FC Bayern München   77000.0  205.0          Right
# 11          Real Madrid   76500.0  355.0          Right
# 12      Atlético Madrid   44000.0  125.0          Right
# 13      Manchester City   60000.0  285.0           Left
# 14              Chelsea   63000.0  225.0          Right
# 15             Juventus   89000.0  205.0           Left
# 16    Tottenham Hotspur   83500.0  205.0          Right
# 17      Atlético Madrid   78000.0  145.0           Left
# 18         FC Barcelona   58000.0  240.0          Right
# 19          Real Madrid   53500.0  240.0           Left
# 20         FC Barcelona   51500.0  315.0          Right
# 21  Paris Saint-Germain   60000.0  200.0          Right
# 22    FC Bayern München   38000.0  130.0          Right
# 23      Manchester City   64500.0  300.0          Right
# 24             Juventus   27000.0  215.0           Left
# 25  Paris Saint-Germain   81000.0  100.0          Right
# 26            Liverpool   69500.0  255.0           Left
# 27          Real Madrid   59500.0  285.0          Right
# 28    FC Bayern München   69500.0  315.0           Left
# 29               Napoli   62000.0  165.0          Right
#
#     International Reputation  Skill Moves Position  Joined  \
# 0                        5.0          4.0       RF    2004
# 1                        5.0          5.0       ST    2018
# 2                        5.0          5.0       LW    2017
# 3                        4.0          1.0       GK    2011
# 4                        4.0          4.0      RCM    2015
# 5                        4.0          4.0       LF    2012
# 6                        4.0          4.0      RCM    2012
# 7                        5.0          3.0       RS    2014
# 8                        4.0          3.0      RCB    2005
# 9                        3.0          1.0       GK    2014
# 10                       4.0          4.0       ST    2014
# 11                       4.0          3.0      LCM    2014
# 12                       3.0          2.0       CB    2010
# 13                       4.0          4.0      LCM    2010
# 14                       3.0          2.0      LDM    2016
# 15                       3.0          4.0       LF    2015
# 16                       3.0          3.0       ST    2010
# 17                       4.0          4.0      CAM    2014
# 18                       3.0          1.0       GK    2014
# 19                       4.0          1.0       GK    2018
# 20                       4.0          3.0      CDM    2008
# 21                       4.0          3.0       LS    2013
# 22                       5.0          1.0       GK    2011
# 23                       4.0          4.0       ST    2011
# 24                       4.0          2.0      LCB    2005
# 25                       3.0          5.0       RM    2018
# 26                       3.0          4.0       RM    2017
# 27                       3.0          2.0      CDM    2013
# 28                       4.0          4.0      LAM    2016
# 29                       3.0          4.0       LW    2010
#
#    Contract_Valid_Until    Height  Weight  Release Clause    Year  Month  \
# 0            2021-01-01  5.583333   159.0   226500.000000  2021.0    1.0
# 1            2022-01-01  6.166667   183.0   127100.000000  2022.0    1.0
# 2            2022-01-01  5.750000   150.0   228100.000000  2022.0    1.0
# 3            2020-01-01  6.333333   168.0   138600.000000  2020.0    1.0
# 4            2023-01-01  5.916667   154.0   196400.000000  2023.0    1.0
# 5            2020-01-01  5.666667   163.0   172100.000000  2020.0    1.0
# 6            2020-01-01  5.666667   146.0   137400.000000  2020.0    1.0
# 7            2021-01-01  6.000000   190.0   164000.000000  2021.0    1.0
# 8            2020-01-01  6.000000   181.0   104600.000000  2020.0    1.0
# 9            2021-01-01  6.166667   192.0   144500.000000  2021.0    1.0
# 10           2021-01-01  6.000000   176.0   127100.000000  2021.0    1.0
# 11           2022-01-01  6.000000   168.0   156800.000000  2022.0    1.0
# 12           2019-01-01  6.166667   172.0    90200.000000  2019.0    1.0
# 13           2020-01-01  5.666667   148.0   111000.000000  2020.0    1.0
# 14           2023-01-01  5.500000   159.0   121300.000000  2023.0    1.0
# 15           2022-01-01  5.833333   165.0   153500.000000  2022.0    1.0
# 16           2024-01-01  6.166667   196.0   160700.000000  2024.0    1.0
# 17           2023-01-01  5.750000   161.0   165800.000000  2023.0    1.0
# 18           2022-01-01  6.166667   187.0   123300.000000  2022.0    1.0
# 19           2024-01-01  6.500000   212.0   113700.000000  2024.0    1.0
# 20           2023-01-01  6.166667   168.0   105600.000000  2023.0    1.0
# 21           2020-01-01  6.083333   170.0   111000.000000  2020.0    1.0
# 22           2021-01-01  6.333333   203.0    62700.000000  2021.0    1.0
# 23           2021-01-01  5.666667   154.0   119300.000000  2021.0    1.0
# 24           2020-01-01  6.166667   187.0    44600.000000  2020.0    1.0
# 25           2022-01-01  5.833333   161.0   166100.000000  2022.0    1.0
# 26           2023-01-01  5.750000   157.0   137300.000000  2023.0    1.0
# 27           2021-01-01  6.083333   185.0   126400.000000  2021.0    1.0
# 28           2019-06-30  5.916667   172.0     4585.060806  2019.0    6.0
# 29           2022-01-01  5.333333   130.0   105400.000000  2022.0    1.0
#
#    Wage_limit
# 0    Too High
# 1    Too High
# 2        High
# 3        High
# 4    Too High
# 5    Too High
# 6    Too High
# 7    Too High
# 8    Too High
# 9   Below_Avg
# 10       High
# 11   Too High
# 12     Medium
# 13       High
# 14       High
# 15       High
# 16       High
# 17     Medium
# 18       High
# 19       High
# 20   Too High
# 21     Medium
# 22     Medium
# 23       High
# 24       High
# 25  Below_Avg
# 26       High
# 27       High
# 28   Too High
# 29     Medium

# %% [markdown]
# ### Is there a relationship between a player's age and their overall rating? How does it vary across different positions?

# %%
filtered_df = df[['Age', 'Overall', 'Position']]
age_group_ratings = filtered_df.groupby('Age')['Overall'].mean()
plt.plot(age_group_ratings.index, age_group_ratings.values)
plt.title("Average Overall Rating by Age")
plt.xlabel("Age")
plt.ylabel("Average Overall Rating")
plt.show()

# %%
positions = filtered_df['Position'].unique()

for position in positions:
    position_df = filtered_df[filtered_df['Position'] == position]
    position_ratings = position_df.groupby('Age')['Overall'].mean()
    
    plt.plot(position_ratings.index, position_ratings.values, label=position)

plt.title("Average Overall Rating by Age and Position")
plt.xlabel("Age")
plt.ylabel("Average Overall Rating")
plt.legend()
plt.show()

# %% [markdown]
# ### Does a player's international reputation impact their overall rating or value? How does it vary across different nationalities?

# %%
filtered_df1 = df[['International Reputation', 'Overall', 'Value', 'Nationality']]
reputation_ratings = filtered_df1.groupby('International Reputation')['Overall'].mean()

plt.bar(reputation_ratings.index, reputation_ratings.values)
plt.title("Average Overall Rating by International Reputation")
plt.xlabel("International Reputation")
plt.ylabel("Average Overall Rating")
plt.show()

# %%
reputation_values = filtered_df1.groupby('International Reputation')['Value'].mean()

plt.bar(reputation_values.index, reputation_values.values)
plt.title("Average Value by International Reputation")
plt.xlabel("International Reputation")
plt.ylabel("Average Value")
plt.show()

# %%
nationalities = filtered_df1['Nationality'].unique()

for nationality in nationalities:
    nationality_df = filtered_df1[filtered_df1['Nationality'] == nationality]
    nationality_ratings = nationality_df.groupby('International Reputation')['Overall'].mean()
    
    plt.plot(nationality_ratings.index, nationality_ratings.values, label=nationality)

plt.title("Average Overall Rating by International Reputation and Nationality")
plt.xlabel("International Reputation")
plt.ylabel("Average Overall Rating")
plt.legend()
plt.show()

# %% [markdown]
# ### How does a player's skill moves rating relate to their overall rating and performance on the field?

# %%
filtered_df2 = df[['Skill Moves', 'Overall']]

# %%
overall_ratings = filtered_df2.groupby('Skill Moves')['Overall'].mean()

plt.plot(overall_ratings.index, overall_ratings.values)
plt.title("Average Overall Rating by Skill Moves")
plt.xlabel("Skill Moves")
plt.ylabel("Average Overall Rating")
plt.show()

# %% [markdown]
# ### What is the distribution of player overall ratings in the dataset? Are there any outliers or patterns?

# %%
overall_ratings = df['Overall']
plt.hist(overall_ratings, bins=20, edgecolor='black')
plt.title('Distribution of Player Overall Ratings')
plt.xlabel('Overall Rating')
plt.ylabel('Frequency')
plt.show()

# %%
rating_mean = overall_ratings.mean()
rating_median = overall_ratings.median()
rating_std = overall_ratings.std()
rating_min = overall_ratings.min()
rating_max = overall_ratings.max()

print("Mean:", rating_mean)
print("Median:", rating_median)
print("Standard Deviation:", rating_std)
print("Minimum Rating:", rating_min)
print("Maximum Rating:", rating_max)
# Out:
# Mean: 66.23869940132916
# Median: 66.0
# Standard Deviation: 6.908929611882886
# Minimum Rating: 46
# Maximum Rating: 94

# %% [markdown]
# ### What is the average overall rating and potential for players in different positions? Are there any positions that consistently have higher-rated players or higher potential?

# %%
position_ratings = df.groupby('Position')['Overall', 'Potential'].mean().reset_index()
position_ratings = position_ratings.sort_values(by='Overall', ascending=False)
plt.figure(figsize=(12, 6))
plt.bar(position_ratings['Position'], position_ratings['Overall'])
plt.title('Average Overall Rating by Position')
plt.xlabel('Position')
plt.ylabel('Average Overall Rating')
plt.xticks(rotation=90)
plt.show()

# %%
position_ratings = position_ratings.sort_values(by='Potential', ascending=False)
plt.figure(figsize=(12, 6))
plt.bar(position_ratings['Position'], position_ratings['Potential'])
plt.title('Average Potential by Position')
plt.xlabel('Position')
plt.ylabel('Average Potential')
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# 0                L. Messi   31   Argentina       94         94
# 1       Cristiano Ronaldo   33    Portugal       94         94
# 2               Neymar Jr   26      Brazil       92         93
# 3                  De Gea   27       Spain       91         93
# 4            K. De Bruyne   27     Belgium       91         92
# ...                   ...  ...         ...      ...        ...
# 18202        J. Lundstram   19     England       47         65
# 18203  N. Christoffersson   19      Sweden       47         63
# 18204           B. Worman   16     England       47         67
# 18205      D. Walker-Rice   17     England       47         66
# 18206           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# 0             FC Barcelona  110500.0  565.0           Left
# 1                 Juventus   77000.0  405.0          Right
# 2      Paris Saint-Germain  118500.0  290.0          Right
# 3        Manchester United   72000.0  260.0          Right
# 4          Manchester City  102000.0  355.0          Right
# ...                    ...       ...    ...            ...
# 18202      Crewe Alexandra      60.0    1.0          Right
# 18203       Trelleborgs FF      60.0    1.0          Right
# 18204     Cambridge United      60.0    1.0          Right
# 18205      Tranmere Rovers      60.0    1.0          Right
# 18206      Tranmere Rovers      60.0    1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                           5.0          4.0       RF    2004
# 1                           5.0          5.0       ST    2018
# 2                           5.0          5.0       LW    2017
# 3                           4.0          1.0       GK    2011
# 4                           4.0          4.0      RCM    2015
# ...                         ...          ...      ...     ...
# 18202                       1.0          2.0       CM    2017
# 18203                       1.0          2.0       ST    2018
# 18204                       1.0          2.0       ST    2017
# 18205                       1.0          2.0       RW    2018
# 18206                       1.0          2.0       CM    2018
#
#       Contract_Valid_Until    Height  Weight  Release Clause    Year  Month  \
# 0               2021-01-01  5.583333   159.0        226500.0  2021.0    1.0
# 1               2022-01-01  6.166667   183.0        127100.0  2022.0    1.0
# 2               2022-01-01  5.750000   150.0        228100.0  2022.0    1.0
# 3               2020-01-01  6.333333   168.0        138600.0  2020.0    1.0
# 4               2023-01-01  5.916667   154.0        196400.0  2023.0    1.0
# ...                    ...       ...     ...             ...     ...    ...
# 18202           2019-01-01  5.750000   134.0           143.0  2019.0    1.0
# 18203           2020-01-01  6.250000   170.0           113.0  2020.0    1.0
# 18204           2021-01-01  5.666667   148.0           165.0  2021.0    1.0
# 18205           2019-01-01  5.833333   154.0           143.0  2019.0    1.0
# 18206           2019-01-01  5.833333   176.0           165.0  2019.0    1.0
#
#       Wage_limit
# 0       Too High
# 1       Too High
# 2           High
# 3           High
# 4       Too High
# ...          ...
# 18202    Too Low
# 18203    Too Low
# 18204    Too Low
# 18205    Too Low
# 18206    Too Low
#
# [18207 rows x 20 columns]
